# %%
# to install
# pip install pandas

# %%
import pandas as pd

# %%
# reading dataset csv
data = pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# reading excel files
# data = pd.read_excel('Iris.xls')     # pip install xlrd
data = pd.read_excel('Iris.xlsx')      # pip install openpyxl
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %%
# plotting datasets
data = pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# plot to a bar graph
count = data['Species'].value_counts().plot(kind='bar')

# %%
# plot to pie chart
data['Species'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Species'>

# %%
# create line chart
data['PetalLengthCm'].value_counts().plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
# reading a dataset from an online csv
ds_url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv"
data = pd.read_csv(ds_url)
data.sample()
# Out:
#     Rank  Major_code         Major    Total     Men   Women  \
# 80    81        3606  MICROBIOLOGY  15232.0  6383.0  8849.0
#
#             Major_category  ShareWomen  Sample_size  Employed  ...  Part_time  \
# 80  Biology & Life Science    0.580948           62      9685  ...       3379
#
#     Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th  P75th  \
# 80                  5080         693           0.066776   38000  29600  50000
#
#     College_jobs  Non_college_jobs  Low_wage_jobs
# 80          5577              3174           1246
#
# [1 rows x 21 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# x='Rank', y='Median', 'P25th', 'P75th'
data.plot(x='Rank',y=['P25th','Median','P75th'])
# Out:
# <AxesSubplot:xlabel='Rank'>

# %%
# kinds
# area, bar, barh, box, hist, line, pie, scatter, hexbin, density

# %%
# distributions
# each column can be used a series
median_col=data['Median']
# type(median_col)
median_col.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# sorting
top5 = data.sort_values(by='Median',ascending=False).head()
top5
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
top5.plot(x='Major',y='Median',kind='bar',fontsize=6,rot=7)
# Out:
# <AxesSubplot:xlabel='Major'>

# %%
# asceding=True is set as default
top_medians = data[data['Median']>60000].sort_values("Median", ascending=False)
top_medians
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# 1    679.0     77.0        Engineering    0.101852            7       640
# 2    725.0    131.0        Engineering    0.153037            3       648
# ...

# %%
top_medians.plot(x="Major",y=['P25th','Median','P75th'],kind='bar',fontsize=5,rot=6)
# Out:
# <AxesSubplot:xlabel='Major'>

# %%
# correlation
# major with higher median = lower chance of unemployment?
data.plot(x="Median",y="Unemployment_rate", kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Median', ylabel='Unemployment_rate'>

# %%
# analyze categorical data using grouping
cat_totals=data.groupby("Major_category")["Total"].sum().sort_values(ascending=True)
cat_totals
# type(data.groupby("Major_category")["Total"])
# dir(data.groupby("Major_category")["Total"])
# Out:
# Major_category
# Interdisciplinary                        12296.0
# Agriculture & Natural Resources          75620.0
# Law & Public Policy                     179107.0
# Physical Sciences                       185479.0
# Industrial Arts & Consumer Services     229792.0
# Computers & Mathematics                 299008.0
# Arts                                    357130.0
# Communications & Journalism             392601.0
# Biology & Life Science                  453862.0
# Health                                  463230.0
# Psychology & Social Work                481007.0
# Social Science                          529966.0
# Engineering                             537583.0
# Education                               559129.0
# Humanities & Liberal Arts               713468.0
# Business                               1302376.0
# Name: Total, dtype: float64

# %%
# plot
cat_totals.plot(kind='barh',fontsize=4)
# Out:
# <AxesSubplot:ylabel='Major_category'>

# %%
# split of categories
small_cat_totals = cat_totals[cat_totals < 220_000]
big_cat_totals = cat_totals[cat_totals >= 220_000]

# merging series to form a new one
small_sums = pd.Series([small_cat_totals.sum()],index=["Other"])

# append to the series to be used
big_cat_totals = big_cat_totals.append(small_sums)

# append using pandas.concat
# big_cat_totals = pd.concat(big_cat_totals,small_sums)

# plot
big_cat_totals.plot(kind='pie',label='')
# Out:
# C:\Users\core360\AppData\Local\Temp\ipykernel_11332\4222407229.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   big_cat_totals = big_cat_totals.append(small_sums)
# <AxesSubplot:>
